# %%
from galileojp.frames import ExperimentFrameGateway
from galileojp.widgets import experiment_dropdown
import matplotlib.pyplot as plt
import pandas as pd
import os

columns = ['name', 'concurrent_requests', 'mean', 'stdev', 'median', 'q25', 'q75', 'q90', 'q99']

def get_names(name, count):
    names = []
    for i in range(1, count + 1):
        names.append((i, name + '-' + str(i)))
    return names

fgw = ExperimentFrameGateway.from_file('../data/prelim_correct.sqlite')

# %%
xp = fgw.experiments()
def id_by_name(name):
    return xp[xp['NAME'] == name]['EXP_ID'].iloc[0]

# %%
pdf_names = get_names('pdf', 10)
mx_names = get_names('mx', 10)
euler_names = get_names('euler', 10)
all_names = get_names('all', 5)
pdf_df = pd.DataFrame(columns=columns)
i = 0
for (concurrent, name) in pdf_names:
    traces = fgw.traces(id_by_name(name))
    mean = traces['RTT'].mean()
    median = traces['RTT'].median()
    std = traces['RTT'].std()
    q25 = traces['RTT'].quantile(q=0.25)
    q75 = traces['RTT'].quantile(q=0.75)
    q90 = traces['RTT'].quantile(q=0.90)
    q99 = traces['RTT'].quantile(q=0.99)
    pdf_df.loc[i] = [name, concurrent, mean, std, median, q25, q75, q90, q99]
    i += 1
    
for (concurrent, name) in euler_names:
    traces = fgw.traces(id_by_name(name))
    mean = traces['RTT'].mean()
    median = traces['RTT'].median()
    std = traces['RTT'].std()
    q25 = traces['RTT'].quantile(q=0.25)
    q75 = traces['RTT'].quantile(q=0.75)
    q90 = traces['RTT'].quantile(q=0.90)
    q99 = traces['RTT'].quantile(q=0.99)
    pdf_df.loc[i] = [name, concurrent, mean, std, median, q25, q75, q90, q99]
    i += 1
    
for (concurrent, name) in mx_names:
    traces = fgw.traces(id_by_name(name))
    mean = traces['RTT'].mean()
    median = traces['RTT'].median()
    std = traces['RTT'].std()
    q25 = traces['RTT'].quantile(q=0.25)
    q75 = traces['RTT'].quantile(q=0.75)
    q90 = traces['RTT'].quantile(q=0.90)
    q99 = traces['RTT'].quantile(q=0.99)
    pdf_df.loc[i] = [name, concurrent, mean, std, median, q25, q75, q90, q99]
    i += 1
    
for (concurrent, name) in all_names:
    traces = fgw.traces(id_by_name(name))
    mean = traces['RTT'].mean()
    median = traces['RTT'].median()
    std = traces['RTT'].std()
    q25 = traces['RTT'].quantile(q=0.25)
    q75 = traces['RTT'].quantile(q=0.75)
    q90 = traces['RTT'].quantile(q=0.90)
    q99 = traces['RTT'].quantile(q=0.99)
    pdf_df.loc[i] = [name, concurrent, mean, std, median, q25, q75, q90, q99]
    i += 1
pdf_df
# Out:
# [(1, 'pdf-1'), (2, 'pdf-2'), (3, 'pdf-3'), (4, 'pdf-4'), (5, 'pdf-5'), (6, 'pdf-6'), (7, 'pdf-7'), (8, 'pdf-8'), (9, 'pdf-9'), (10, 'pdf-10')]
#         name concurrent_requests         mean       stdev       median  \
# 0      pdf-1                   1   129.253077   10.724418   127.091169
# 1      pdf-2                   2   233.835136   20.838522   228.269815
# 2      pdf-3                   3   232.785584   18.828972   231.365681
# 3      pdf-4                   4   457.534060   36.428479   445.292473
# 4      pdf-5                   5   566.709208   46.747317   548.806190
# 5      pdf-6                   6   674.993367   51.920377   656.072378
# 6      pdf-7                   7   790.177721   65.052432   768.903971
# 7      pdf-8                   8   905.203479   67.181694   879.574299
# 8      pdf-9                   9  1012.252204   76.302803   989.988804
# 9     pdf-10                  10  1135.895727   86.516101  1100.897074
# 10   euler-1                   1   195.424365   18.882911   189.589500
# 11   euler-2                   2   367.164063   37.431575   361.892462
# 12   euler-3                   3   537.289206   39.250097   532.719135
# 13   euler-4                   4   709.209283   48.384859   695.956230
# 14   euler-5                   5   897.762720   59.654089   913.751364
# 15   euler-6                   6  1082.660873   79.916340  1103.209496
# 16   euler-7                   7  1263.840594   89.169336  1287.806749
# 17   euler-8                   8  1424.931491   94.552133  1393.610716
# 18   euler-9                   9  1604.688247  101.334276  1587.606192
# 19  euler-10                  10  1779.133033  115.939732  1745.720625
# 20      mx-1                   1          NaN         NaN          NaN
# 21      mx-2                   2    88.102593   13.185507    85.760355
# 22      mx-3                   3    85.708914   10.402099    84.491730
# 23      mx-4                   4   259.934502   28.783307   253.171325
# 24      mx-5                   5   320.451632   25.231186   315.375328
# 25      mx-6                   6   396.709881   66.911572   381.079912
# 26      mx-7                   7   447.953095   27.765898   443.011761
# 27      mx-8                   8   525.387976   74.900711   509.889722
# 28      mx-9                   9   573.386810   37.500887   568.971634
# 29     mx-10                  10   640.751498   35.783679   637.531877
# 30     all-1                   1   192.813039   17.417774   187.838793
# 31     all-2                   2   360.040738   31.193348   354.519606
# 32     all-3                   3   543.405385   39.383945   548.256874
# 33     all-4                   4   759.447533   71.446978   750.065088
# 34     all-5                   5   904.326713   63.447263   913.350344
#
#             q25          q75          q90          q99
# 0    121.722341   133.910418   141.345263   161.765480
# 1    220.358372   246.114016   257.102728   302.114792
# 2    218.865156   246.054590   254.530931   282.231803
# 3    433.308005   490.292192   509.095645   540.698242
# 4    538.631678   602.169514   635.427284   693.045626
# 5    643.518627   712.571621   757.272863   793.446262
# 6    751.662970   839.427710   888.357115   945.373917
# 7    862.307727   964.989960  1015.646148  1051.461000
# 8    969.880879  1023.914576  1138.243389  1200.482817
# 9   1084.725559  1221.958697  1272.158337  1317.879717
# 10   183.018684   202.444911   220.382023   254.567447
# 11   338.215530   379.509866   424.402428   471.437790
# 12   505.770564   564.467907   583.394861   646.407380
# 13   673.836470   742.243767   765.106487   849.717903
# 14   846.736431   939.558029   961.744022  1041.350174
# 15  1020.107269  1130.326509  1149.746180  1305.800343
# 16  1187.211812  1318.107665  1347.354650  1473.811996
# 17  1354.255915  1497.135878  1533.513737  1677.121353
# 18  1525.133252  1687.348187  1712.308502  1842.094510
# 19  1692.552567  1862.447381  1904.118538  2097.622724
# 20          NaN          NaN          NaN          NaN
# 21    80.200016    91.661215   101.669884   138.220608
# 22    78.672767    89.713991    95.889902   123.209143
# 23   243.481755   268.669546   282.855797   384.709795
# 24   305.179238   330.430627   346.427679   418.509221
# 25   369.582653   398.105145   420.441914   739.356451
# 26   430.509925   459.460020   480.519772   527.962184
# 27   493.153512   530.001581   559.668732   923.103888
# 28   552.110314   591.388226   611.696434   677.304869
# 29   621.299267   657.669604   683.337235   715.018220
# 30   180.363059   198.014975   218.197203   252.756686
# 31   338.880897   373.553038   391.831303   500.656242
# 32   507.065177   567.141771   594.907260   636.811242
# 33   711.023510   807.679057   847.363234   975.742877
# 34   850.689054   939.837337   970.051908  1068.004169
